# %% [markdown]
# <center>
#     <img src='images/small-uai.jpeg'style="width: 300px;">
# </center>
#
# ## Laboratorio S03.2: _Deep Learning_ - _Transfer Learning_
#
# #### Curso: Aprendizaje profundo
#
# <center>
#     <img src='images/intro-DL.png'style="width: 900px;">
#     <sub><sup>https://www.researchgate.net/figure/A-standard-architecture-of-a-deep-learning-convolutional-neural-network_fig1_316955338</sup></sub>
# </center>
#
# **Profesor**: Dr. Juan Bekios Calfa
#
# **Grado**: MIA

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1. Cargar las librerías

# %%
import torch
import torchvision
from torchvision import transforms, datasets
import PIL

# %% [markdown]
# ## 2. Cargar imágenes
#
# Se cargan las imágenes utilizando la clase **ImageFolder**. La clase ImageForder etiqueta automáticamente las imágenes dada una ruta donde se encuentran los datos. Por ejemplo, si tengo el directorio raíz dataset/training_set. Debo dejar mis imágenes de cada clase en una carpeta diferente. Si tengo imágenes de gatos debo dejarlos en dataset/training_set/cats, si tengo imágenes de perros las debo dejar en dataset/training_set/dogs, etc.

# %%
data_transform = transforms.Compose([
        transforms.Resize((128,128)),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandomGrayscale(p=0.2),
        transforms.RandomAffine(degrees=0, translate=(0.1, 0.1),
                                scale=None, shear=None,
                                resample=False, fillcolor=0),
        transforms.ColorJitter(brightness=(1, 1.5),
                               contrast=(0.3, 2),
                               saturation=(0.2, 2),
                               hue=(-0.3, 0.3)),
        transforms.RandomRotation((-5, 5), resample=PIL.Image.BILINEAR),
        transforms.ToTensor()
    ])
gatos_perros_dataset = datasets.ImageFolder(root='/content/drive/My Drive/D-UCN/Classes/TecnicasAvanzadasAprendizajeAutomatico/Laboratorios/Laboratorio05.2:DeepLearning/dataset/training_set',
                                           transform=data_transform)
print(gatos_perros_dataset)
dataset_loader = torch.utils.data.DataLoader(gatos_perros_dataset,
                                             batch_size=32, shuffle=False,
                                             num_workers=0)
print(dataset_loader)
# Out:
# Dataset ImageFolder
#     Number of datapoints: 6000
#     Root location: /content/drive/My Drive/D-UCN/Classes/TecnicasAvanzadasAprendizajeAutomatico/Laboratorios/Laboratorio05.2:DeepLearning/dataset/training_set
#     StandardTransform
# Transform: Compose(
#                Resize(size=(128, 128), interpolation=bilinear)
#                RandomHorizontalFlip(p=0.5)
#                RandomGrayscale(p=0.2)
#                RandomAffine(degrees=[0.0, 0.0], translate=(0.1, 0.1))
#                ColorJitter(brightness=(1, 1.5), contrast=(0.3, 2), saturation=(0.2, 2), hue=(-0.3, 0.3))
#                RandomRotation(degrees=[-5.0, 5.0], interpolation=bilinear, expand=False, fill=0)
#                ToTensor()
#            )
# <torch.utils.data.dataloader.DataLoader object at 0x7f97854c2790>
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:1315: UserWarning: Argument resample is deprecated and will be removed since v0.10.0. Please, use interpolation instead
#   "Argument resample is deprecated and will be removed since v0.10.0. Please, use interpolation instead"
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:1329: UserWarning: Argument fillcolor is deprecated and will be removed since v0.10.0. Please, use fill instead
#   "Argument fillcolor is deprecated and will be removed since v0.10.0. Please, use fill instead"
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:1201: UserWarning: Argument resample is deprecated and will be removed since v0.10.0. Please, use interpolation instead
#   "Argument resample is deprecated and will be removed since v0.10.0. Please, use interpolation instead"

# %% [markdown]
# ## 3. Visualizo las imágenes cargadas

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(num=None, figsize=(12, 8), dpi=80, facecolor='w', edgecolor='k')

def imshow(img):
  np_img = img.numpy()
  plt.imshow(np.transpose(np_img, (1, 2, 0)))

# Obtener imagenes
data_iter = iter(dataset_loader)
images, labels = data_iter.next()

# Mostrar imagenes
imshow(torchvision.utils.make_grid(images))

# %% [markdown]
# ## 4. Separando la base de datos
#
# Para realizar el entrenamiento y pruebas se recomienda separar los datos en tres conjuntos:
#
# * **Conjunto de entrenamiento:** El modelo aprende de los ejemplos de este conjunto de datos. Se ajusta un parámetro a un clasificador.
# * **Conjunto de validación:** Los ejemplos en el conjunto de datos de validación se utilizan para ajustar los hiperparámetros, como la tasa de aprendizaje y las épocas. El objetivo de crear un conjunto de validación es evitar un sobreajuste grande del modelo. Es un punto de control para saber si el modelo se ajusta bien con el conjunto de datos de entrenamiento.
# * **Conjunto de pruebas:** Este conjunto de datos prueba la evolución final del modelo, midiendo qué tan bien aprendió y predijo el resultado deseado. Contiene datos invisibles de la vida real. Es un conjunto diferente al de entrenamiento y validación.
#
# Imagen: [https://i.imgur.com/DV80uhS.png](https://i.imgur.com/DV80uhS.png)

# %%
# Transformaciones sobre las imágenes
data_transform = transforms.Compose([
        transforms.Resize((32,32)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406],
                             std=[0.229, 0.224, 0.225])
    ])

# Carga de las imágenes
gatos_perros_train = datasets.ImageFolder(root='/content/drive/My Drive/D-UCN/Classes/TecnicasAvanzadasAprendizajeAutomatico/Laboratorios/Laboratorio05.2:DeepLearning/dataset/training_set',
                                           transform=data_transform)
gatos_perros_valid = datasets.ImageFolder(root='/content/drive/My Drive/D-UCN/Classes/TecnicasAvanzadasAprendizajeAutomatico/Laboratorios/Laboratorio05.2:DeepLearning/dataset/valid_set',
                                           transform=data_transform)
gatos_perros_test = datasets.ImageFolder(root='/content/drive/My Drive/D-UCN/Classes/TecnicasAvanzadasAprendizajeAutomatico/Laboratorios/Laboratorio05.2:DeepLearning/dataset/test_set',
                                           transform=data_transform)

# Conjunto de entrenamiento
train_loader = torch.utils.data.DataLoader(gatos_perros_train,
                                             batch_size=32, shuffle=True,
                                             num_workers=2)

# Conjunto de validación
valid_loader = torch.utils.data.DataLoader(gatos_perros_valid,
                                             batch_size=32, shuffle=False,
                                             num_workers=2)

# Conjunto de pruebas
test_loader = torch.utils.data.DataLoader(gatos_perros_test,
                                             batch_size=32, shuffle=False,
                                             num_workers=2)

# %% [markdown]
# ### Revisamos las imagenes de las nuevas cargas

# %%
plt.figure(num=None, figsize=(12, 8), dpi=80, facecolor='w', edgecolor='k')

# Obtener imagenes
data_iter = iter(valid_loader)
images, labels = data_iter.next()

# Mostrar imagenes
imshow(torchvision.utils.make_grid(images))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## 5. El modelo
#
# Construimos un modelo con dos capas convolucionales, un dropout y dos capas completamente conectadas para la clasificación.
#
# * Imagen red: [https://i.imgur.com/wiP9IwZ.png](https://i.imgur.com/wiP9IwZ.png)
# * Imagen Conv: https://i.imgur.com/E9GGJMJ.gif
# * Imagen Pool: https://i.imgur.com/kSwID7J.png

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class CNN(nn.Module): 
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=10, kernel_size=3)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=3)
        self.conv2_drop = nn.Dropout2d()
        self.fc1 = nn.Linear(720, 1024)
        self.fc2 = nn.Linear(1024, 2)

    def forward(self, x): # Calcular la predicción
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        x = x.view(x.shape[0],-1)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return x

# %% [markdown]
# ### Creamos el modelo

# %%
model = CNN()
print(model)
# Out:
# CNN(
#   (conv1): Conv2d(3, 10, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(10, 20, kernel_size=(3, 3), stride=(1, 1))
#   (conv2_drop): Dropout2d(p=0.5, inplace=False)
#   (fc1): Linear(in_features=720, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=2, bias=True)
# )

# %% [markdown]
# ## 6. Optimización
#
# Seleccionamos cualquier algoritmo optimizador disponible en el paquete `torch.optim`. En general, los optimizadores son moficaciones del descenso del gradiente. Cambiando los parámetros del modelo, como los pesos, y añadiendo sesgo, el modelo puede ser optimizado. La **tasa de aprendizaje** decidirá cuán grandes deben ser los pasos para cambiar los parámetros.
#
# * Calcular lo que un pequeño cambio en cada peso haría a la función de pérdida (seleccionando la dirección para alcanzar los mínimos).
# * Ajustar cada peso en función de su gradiente (es decir, dar un pequeño paso en la dirección determinada).
# * Continúe haciendo los pasos 1 y 2 hasta que la función de pérdida sea lo más baja posible.
#
# Aquí, la estimación del momento adaptativo (*adaptive moment estimation* - Adam) se utiliza como un optimizador. Es una mezcla de **RMSprop** y **descenso de gradiente estocástico**.
#
# ### Configuración de Hyperparámetros

# %%
# Hyper parameters
num_epochs = 35
num_classes = 2
batch_size = 25
learning_rate = 0.01

# %% [markdown]
# ### Configuración del dispositivo

# %%
# CPU or GPU

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# ### Optimizador

# %%
model = CNN().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(),lr = learning_rate)

# %% [markdown]
# ## 7. Entrenamiento

# %%
# %%timeit
# keeping-track-of-losses 
train_losses = []
valid_losses = []

for epoch in range(1, num_epochs + 1):
    # keep-track-of-training-and-validation-loss
    train_loss = 0.0
    valid_loss = 0.0
    
    # training-the-model
    model.train()
    for data, target in train_loader:
        # move-tensors-to-GPU 
        data = data.to(device)
        target = target.to(device)
        
        # clear-the-gradients-of-all-optimized-variables
        optimizer.zero_grad()
        # forward-pass: compute-predicted-outputs-by-passing-inputs-to-the-model
        output = model(data)
        # calculate-the-batch-loss
        loss = criterion(output, target)
        # backward-pass: compute-gradient-of-the-loss-wrt-model-parameters
        loss.backward()
        # perform-a-ingle-optimization-step (parameter-update)
        optimizer.step()
        # update-training-loss
        train_loss += loss.item() * data.size(0)
        
    # validate-the-model
    model.eval()
    for data, target in valid_loader:
        
        data = data.to(device)
        target = target.to(device)
        
        output = model(data)
        
        loss = criterion(output, target)
        
        # update-average-validation-loss 
        valid_loss += loss.item() * data.size(0)
    
    # calculate-average-losses
    train_loss = train_loss/len(train_loader.sampler)
    valid_loss = valid_loss/len(valid_loader.sampler)
    train_losses.append(train_loss)
    valid_losses.append(valid_loss)
        
    # print-training/validation-statistics 
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch, train_loss, valid_loss))
# Out:
# Epoch: 1 	Training Loss: 0.738520 	Validation Loss: 0.693158
# Epoch: 2 	Training Loss: 0.694573 	Validation Loss: 0.693414
# Epoch: 3 	Training Loss: 0.693719 	Validation Loss: 0.693558
# Epoch: 4 	Training Loss: 0.694486 	Validation Loss: 0.693158
# Epoch: 5 	Training Loss: 0.693525 	Validation Loss: 0.693389
# Epoch: 6 	Training Loss: 0.693657 	Validation Loss: 0.693159
# Epoch: 7 	Training Loss: 0.693386 	Validation Loss: 0.694069
# Epoch: 8 	Training Loss: 0.693538 	Validation Loss: 0.693694
# Epoch: 9 	Training Loss: 0.693442 	Validation Loss: 0.693192
# Epoch: 10 	Training Loss: 0.693344 	Validation Loss: 0.696429
# Epoch: 11 	Training Loss: 0.694226 	Validation Loss: 0.693239
# Epoch: 12 	Training Loss: 0.693849 	Validation Loss: 0.693149
# Epoch: 13 	Training Loss: 0.693865 	Validation Loss: 0.693243
# Epoch: 14 	Training Loss: 0.693449 	Validation Loss: 0.693201
# Epoch: 15 	Training Loss: 0.693663 	Validation Loss: 0.693422
# Epoch: 16 	Training Loss: 0.693571 	Validation Loss: 0.693200
# Epoch: 17 	Training Loss: 0.693360 	Validation Loss: 0.694034
# Epoch: 18 	Training Loss: 0.693458 	Validation Loss: 0.694155
# Epoch: 19 	Training Loss: 0.693765 	Validation Loss: 0.693516
# Epoch: 20 	Training Loss: 0.693632 	Validation Loss: 0.693282
# Epoch: 21 	Training Loss: 0.693774 	Validation Loss: 0.693521
# Epoch: 22 	Training Loss: 0.693646 	Validation Loss: 0.693206
# Epoch: 23 	Training Loss: 0.693517 	Validation Loss: 0.693149
# Epoch: 24 	Training Loss: 0.693141 	Validation Loss: 0.694954
# Epoch: 25 	Training Loss: 0.693400 	Validation Loss: 0.694221
# Epoch: 26 	Training Loss: 0.693766 	Validation Loss: 0.693402
# Epoch: 27 	Training Loss: 0.693719 	Validation Loss: 0.693152
# Epoch: 28 	Training Loss: 0.693155 	Validation Loss: 0.694959
# Epoch: 29 	Training Loss: 0.693555 	Validation Loss: 0.693166
# Epoch: 30 	Training Loss: 0.693666 	Validation Loss: 0.693160
# Epoch: 31 	Training Loss: 0.693559 	Validation Loss: 0.693151
# Epoch: 32 	Training Loss: 0.693545 	Validation Loss: 0.693427
# Epoch: 33 	Training Loss: 0.693493 	Validation Loss: 0.693713
# Epoch: 34 	Training Loss: 0.693728 	Validation Loss: 0.693161
# Epoch: 35 	Training Loss: 0.693546 	Validation Loss: 0.693167
# Epoch: 1 	Training Loss: 0.693886 	Validation Loss: 0.693532
# Epoch: 2 	Training Loss: 0.693570 	Validation Loss: 0.693558
# Epoch: 3 	Training Loss: 0.694085 	Validation Loss: 0.693237
# Epoch: 4 	Training Loss: 0.693077 	Validation Loss: 0.694627
# Epoch: 5 	Training Loss: 0.693548 	Validation Loss: 0.694538
# Epoch: 6 	Training Loss: 0.693517 	Validation Loss: 0.693586
# Epoch: 7 	Training Loss: 0.693765 	Validation Loss: 0.693180
# Epoch: 8 	Training Loss: 0.693380 	Validation Loss: 0.693741
# Epoch: 9 	Training Loss: 0.693451 	Validation Loss: 0.693195
# Epoch: 10 	Training Loss: 0.693594 	Validation Loss: 0.693177
# Epoch: 11 	Training Loss: 0.693535 	Validation Loss: 0.694073
# Epoch: 12 	Training Loss: 0.693915 	Validation Loss: 0.693245
# Epoch: 13 	Training Loss: 0.693685 	Validation Loss: 0.693533
# Epoch: 14 	Training Loss: 0.693442 	Validation Loss: 0.693657
# Epoch: 15 	Training Loss: 0.693404 	Validation Loss: 0.693839
# Epoch: 16 	Training Loss: 0.693657 	Validation Loss: 0.693546
# Epoch: 17 	Training Loss: 0.693377 	Validation Loss: 0.693308
# Epoch: 18 	Training Loss: 0.693654 	Validation Loss: 0.693408
# Epoch: 19 	Training Loss: 0.693689 	Validation Loss: 0.693189
# Epoch: 20 	Training Loss: 0.693578 	Validation Loss: 0.693169
# Epoch: 21 	Training Loss: 0.693576 	Validation Loss: 0.693152
# Epoch: 22 	Training Loss: 0.693329 	Validation Loss: 0.693479
# Epoch: 23 	Training Loss: 0.693558 	Validation Loss: 0.693888
# Epoch: 24 	Training Loss: 0.693695 	Validation Loss: 0.693206
# Epoch: 25 	Training Loss: 0.693694 	Validation Loss: 0.693159
# Epoch: 26 	Training Loss: 0.693534 	Validation Loss: 0.695180
# Epoch: 27 	Training Loss: 0.693744 	Validation Loss: 0.693150
# Epoch: 28 	Training Loss: 0.693711 	Validation Loss: 0.693182
# Epoch: 29 	Training Loss: 0.693918 	Validation Loss: 0.693423
# Epoch: 30 	Training Loss: 0.693648 	Validation Loss: 0.693147
# Epoch: 31 	Training Loss: 0.693941 	Validation Loss: 0.693454
# Epoch: 32 	Training Loss: 0.693534 	Validation Loss: 0.695167
# Epoch: 33 	Training Loss: 0.693902 	Validation Loss: 0.693464
# Epoch: 34 	Training Loss: 0.693719 	Validation Loss: 0.693227
# Epoch: 35 	Training Loss: 0.693579 	Validation Loss: 0.693220
# Epoch: 1 	Training Loss: 0.693344 	Validation Loss: 0.693577
# Epoch: 2 	Training Loss: 0.694020 	Validation Loss: 0.693852
# Epoch: 3 	Training Loss: 0.693678 	Validation Loss: 0.694011
# Epoch: 4 	Training Loss: 0.693802 	Validation Loss: 0.693353
# Epoch: 5 	Training Loss: 0.693813 	Validation Loss: 0.693224
# Epoch: 6 	Training Loss: 0.693826 	Validation Loss: 0.693185
# Epoch: 7 	Training Loss: 0.693537 	Validation Loss: 0.694014
# Epoch: 8 	Training Loss: 0.693776 	Validation Loss: 0.693201
# Epoch: 9 	Training Loss: 0.693520 	Validation Loss: 0.693699
# Epoch: 10 	Training Loss: 0.693600 	Validation Loss: 0.693244
# Epoch: 11 	Training Loss: 0.693404 	Validation Loss: 0.693485
# Epoch: 12 	Training Loss: 0.693401 	Validation Loss: 0.693843
# Epoch: 13 	Training Loss: 0.693815 	Validation Loss: 0.693182
# Epoch: 14 	Training Loss: 0.693702 	Validation Loss: 0.693172
# Epoch: 15 	Training Loss: 0.693620 	Validation Loss: 0.693338
# Epoch: 16 	Training Loss: 0.693801 	Validation Loss: 0.693367
# Epoch: 17 	Training Loss: 0.693663 	Validation Loss: 0.694047
# Epoch: 18 	Training Loss: 0.693562 	Validation Loss: 0.693272
# Epoch: 19 	Training Loss: 0.693078 	Validation Loss: 0.693290
# Epoch: 20 	Training Loss: 0.693609 	Validation Loss: 0.693487
# Epoch: 21 	Training Loss: 0.693804 	Validation Loss: 0.693268
# Epoch: 22 	Training Loss: 0.693810 	Validation Loss: 0.693177
# Epoch: 23 	Training Loss: 0.693541 	Validation Loss: 0.693199
# Epoch: 24 	Training Loss: 0.693679 	Validation Loss: 0.693893
# Epoch: 25 	Training Loss: 0.693750 	Validation Loss: 0.694693
# Epoch: 26 	Training Loss: 0.694138 	Validation Loss: 0.693166
# Epoch: 27 	Training Loss: 0.693797 	Validation Loss: 0.693171
# Epoch: 28 	Training Loss: 0.693498 	Validation Loss: 0.693166
# Epoch: 29 	Training Loss: 0.693758 	Validation Loss: 0.693441
# Epoch: 30 	Training Loss: 0.693676 	Validation Loss: 0.693240
# Epoch: 31 	Training Loss: 0.693734 	Validation Loss: 0.693229
# Epoch: 32 	Training Loss: 0.693986 	Validation Loss: 0.693212
# Epoch: 33 	Training Loss: 0.693549 	Validation Loss: 0.693205
# Epoch: 34 	Training Loss: 0.693623 	Validation Loss: 0.693489
# Epoch: 35 	Training Loss: 0.693725 	Validation Loss: 0.693198
# Epoch: 1 	Training Loss: 0.693882 	Validation Loss: 0.693731
# Epoch: 2 	Training Loss: 0.693573 	Validation Loss: 0.693148
# Epoch: 3 	Training Loss: 0.693729 	Validation Loss: 0.694142
# Epoch: 4 	Training Loss: 0.693714 	Validation Loss: 0.693201
# Epoch: 5 	Training Loss: 0.693579 	Validation Loss: 0.693148
# Epoch: 6 	Training Loss: 0.693253 	Validation Loss: 0.694144
# Epoch: 7 	Training Loss: 0.693698 	Validation Loss: 0.693371
# Epoch: 8 	Training Loss: 0.693716 	Validation Loss: 0.693506
# Epoch: 9 	Training Loss: 0.693690 	Validation Loss: 0.693514
# Epoch: 10 	Training Loss: 0.693759 	Validation Loss: 0.693380
# Epoch: 11 	Training Loss: 0.692961 	Validation Loss: 0.693182
# Epoch: 12 	Training Loss: 0.693626 	Validation Loss: 0.693878
# Epoch: 13 	Training Loss: 0.693463 	Validation Loss: 0.693330
# Epoch: 14 	Training Loss: 0.693438 	Validation Loss: 0.693642
# Epoch: 15 	Training Loss: 0.693411 	Validation Loss: 0.693150
# Epoch: 16 	Training Loss: 0.693990 	Validation Loss: 0.693402
# Epoch: 17 	Training Loss: 0.693357 	Validation Loss: 0.696267
# Epoch: 18 	Training Loss: 0.693564 	Validation Loss: 0.694323
# Epoch: 19 	Training Loss: 0.693633 	Validation Loss: 0.693171
# Epoch: 20 	Training Loss: 0.693449 	Validation Loss: 0.693553
# Epoch: 21 	Training Loss: 0.693520 	Validation Loss: 0.693216
# Epoch: 22 	Training Loss: 0.693305 	Validation Loss: 0.693158
# Epoch: 23 	Training Loss: 0.693229 	Validation Loss: 0.694821
# Epoch: 24 	Training Loss: 0.693925 	Validation Loss: 0.693885
# Epoch: 25 	Training Loss: 0.693616 	Validation Loss: 0.693161
# Epoch: 26 	Training Loss: 0.692907 	Validation Loss: 0.695592
# Epoch: 27 	Training Loss: 0.693672 	Validation Loss: 0.693203
# Epoch: 28 	Training Loss: 0.693592 	Validation Loss: 0.693370
# Epoch: 29 	Training Loss: 0.693536 	Validation Loss: 0.693414
# Epoch: 30 	Training Loss: 0.693527 	Validation Loss: 0.693424
# Epoch: 31 	Training Loss: 0.693721 	Validation Loss: 0.693217
# Epoch: 32 	Training Loss: 0.693343 	Validation Loss: 0.693219
# Epoch: 33 	Training Loss: 0.693815 	Validation Loss: 0.693436
# Epoch: 34 	Training Loss: 0.693626 	Validation Loss: 0.693244
# Epoch: 35 	Training Loss: 0.693682 	Validation Loss: 0.693830
# 1 loop, best of 3: 16min 26s per loop

# %% [markdown]
# ## 8. Pruebas

# %%
# test-the-model
model.eval()  # it-disables-dropout
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
          
    print('Test Accuracy of the model: {} %'.format(100 * correct / total))

# Save 
torch.save(model.state_dict(), 'model.ckpt')

# %% [markdown]
# 9. Graficamos los resultados

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

plt.plot(train_losses, label='Training loss')
plt.plot(valid_losses, label='Validation loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(frameon=False)
